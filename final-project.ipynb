# %%
import pandas as pd
import geopandas as gpd

# Define file paths (update these paths based on your local directory)
file_paths = {
    "listings": "data/listings.csv.gz",
    "calendar": "data/calendar.csv.gz",
    "reviews": "data/reviews.csv.gz",
    "listings_summary": "data/listings.csv",
    "reviews_summary": "data/reviews.csv",
    "neighbourhoods": "data/neighbourhoods.csv",
    "neighbourhoods_geojson": "data/neighbourhoods.geojson"
}

# Load files into individual dataframes
listings = pd.read_csv(file_paths["listings"], low_memory=False)
calendar = pd.read_csv(file_paths["calendar"], low_memory=False)
reviews = pd.read_csv(file_paths["reviews"], low_memory=False)
listings_summary = pd.read_csv(file_paths["listings_summary"], low_memory=False)
reviews_summary = pd.read_csv(file_paths["reviews_summary"], low_memory=False)
neighbourhoods = pd.read_csv(file_paths["neighbourhoods"], low_memory=False)
neighbourhoods_geojson = gpd.read_file(file_paths["neighbourhoods_geojson"])

# Display summary and head of each dataframe
dataframes = {
    "listings": listings,
    "calendar": calendar,
    "reviews": reviews,
    "listings_summary": listings_summary,
    "reviews_summary": reviews_summary,
    "neighbourhoods": neighbourhoods,
    "neighbourhoods_geojson": neighbourhoods_geojson
}

for df_name, df in dataframes.items():
    print(f"DataFrame name: {df_name}")
    print(f"Summary of {df_name}:")
    print(df.info())
    print(f"\nFirst 5 rows of {df_name}:")
    print(df.head())
    print("\n")
# Out:
# DataFrame name: listings
# Summary of listings:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18230 entries, 0 to 18229
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18230 non-null  int64
#  1   listing_url                                   18230 non-null  object
#  2   scrape_id                                     18230 non-null  int64
#  3   last_scraped                                  18230 non-null  object
#  4   source                                        18230 non-null  object
#  5   name                                          18230 non-null  object
#  6   description                                   0 non-null      float64
#  7   neighborhood_overview                         11081 non-null  object
#  8   picture_url                                   18230 non-null  object
#  9   host_id                                       18230 non-null  int64
#  10  host_url                                      18230 non-null  object
#  11  host_name                                     18226 non-null  object
#  12  host_since                                    18226 non-null  object
#  13  host_location                                 13498 non-null  object
#  14  host_about                                    9738 non-null   object
#  15  host_response_time                            16272 non-null  object
#  16  host_response_rate                            16272 non-null  object
#  17  host_acceptance_rate                          16802 non-null  object
#  18  host_is_superhost                             18209 non-null  object
#  19  host_thumbnail_url                            18226 non-null  object
#  20  host_picture_url                              18226 non-null  object
#  21  host_neighbourhood                            11866 non-null  object
#  22  host_listings_count                           18226 non-null  float64
#  23  host_total_listings_count                     18226 non-null  float64
#  24  host_verifications                            18226 non-null  object
#  25  host_has_profile_pic                          18226 non-null  object
#  26  host_identity_verified                        18226 non-null  object
#  27  neighbourhood                                 11081 non-null  object
#  28  neighbourhood_cleansed                        18230 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      18230 non-null  float64
#  31  longitude                                     18230 non-null  float64
#  32  property_type                                 18230 non-null  object
#  33  room_type                                     18230 non-null  object
#  34  accommodates                                  18230 non-null  int64
#  35  bathrooms                                     0 non-null      float64
#  36  bathrooms_text                                18211 non-null  object
#  37  bedrooms                                      8 non-null      float64
#  38  beds                                          17959 non-null  float64
#  39  amenities                                     18230 non-null  object
#  40  price                                         17457 non-null  object
#  41  minimum_nights                                18230 non-null  int64
#  42  maximum_nights                                18230 non-null  int64
#  43  minimum_minimum_nights                        18230 non-null  int64
#  44  maximum_minimum_nights                        18230 non-null  int64
#  45  minimum_maximum_nights                        18230 non-null  int64
#  46  maximum_maximum_nights                        18230 non-null  int64
#  47  minimum_nights_avg_ntm                        18230 non-null  float64
#  48  maximum_nights_avg_ntm                        18230 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              17457 non-null  object
#  51  availability_30                               18230 non-null  int64
#  52  availability_60                               18230 non-null  int64
#  53  availability_90                               18230 non-null  int64
#  54  availability_365                              18230 non-null  int64
#  55  calendar_last_scraped                         18230 non-null  object
#  56  number_of_reviews                             18230 non-null  int64
#  57  number_of_reviews_ltm                         18230 non-null  int64
#  58  number_of_reviews_l30d                        18230 non-null  int64
#  59  first_review                                  14284 non-null  object
#  60  last_review                                   14284 non-null  object
#  61  review_scores_rating                          14290 non-null  float64
#  62  review_scores_accuracy                        14287 non-null  float64
#  63  review_scores_cleanliness                     14287 non-null  float64
#  64  review_scores_checkin                         14287 non-null  float64
#  65  review_scores_communication                   14287 non-null  float64
#  66  review_scores_location                        14286 non-null  float64
#  67  review_scores_value                           14286 non-null  float64
#  68  license                                       1 non-null      object
#  69  instant_bookable                              18230 non-null  object
#  70  calculated_host_listings_count                18230 non-null  int64
#  71  calculated_host_listings_count_entire_homes   18230 non-null  int64
#  72  calculated_host_listings_count_private_rooms  18230 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   18230 non-null  int64
#  74  reviews_per_month                             14284 non-null  float64
# dtypes: float64(20), int64(21), object(34)
# memory usage: 10.4+ MB
# None
#
# First 5 rows of listings:
#        id                          listing_url       scrape_id last_scraped  \
# 0   57818   https://www.airbnb.com/rooms/57818  20231225202534   2023-12-26
# 1   69824   https://www.airbnb.com/rooms/69824  20231225202534   2023-12-26
# 2   83449   https://www.airbnb.com/rooms/83449  20231225202534   2023-12-27
# 3  105411  https://www.airbnb.com/rooms/105411  20231225202534   2023-12-26
# 4  129099  https://www.airbnb.com/rooms/129099  20231225202534   2023-12-26
#
#         source                                               name  \
# 0  city scrape  Home in Hollywood · ★4.63 · 2 bedrooms · 2 bed...
# 1  city scrape  Rental unit in Hallandale · ★4.0 · 2 bedrooms ...
# 2  city scrape  Rental unit in Dania Beach · ★4.77 · 2 bedroom...
# 3  city scrape  Rental unit in Southwest Ranches · ★5.0 · 3 be...
# 4  city scrape  Condo in Hollywood · ★4.29 · 1 bedroom · 2 bed...
#
#    description                              neighborhood_overview  \
# 0          NaN  Check-in window<br />After 3:00 PM<br />Edit<b...
# 1          NaN                                                NaN
# 2          NaN  Residential neighborhood, less than 2 miles to...
# 3          NaN  Very close to I75, one of the main highways. Y...
# 4          NaN                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...   275948  ...
# 1  https://a0.muscache.com/pictures/443102/f6b94e...   351303  ...
# 2  https://a0.muscache.com/pictures/8c21bda0-5194...   454736  ...
# 3  https://a0.muscache.com/pictures/787317/2cc18e...   532930  ...
# 4  https://a0.muscache.com/pictures/828393/baabb6...   637272  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.97                   4.88                4.71
# 1                        4.75                   5.00                4.50
# 2                        4.90                   4.81                4.87
# 3                        5.00                   4.25                5.00
# 4                        4.32                   4.54                4.08
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              2
# 1     NaN                f                              2
# 2     NaN                f                             15
# 3     NaN                f                              1
# 4     NaN                f                              5
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           2
# 1                                           2
# 2                                          15
# 3                                           1
# 4                                           5
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.43
# 1                                           0              0.12
# 2                                           0              0.21
# 3                                           0              0.03
# 4                                           0              0.18
#
# [5 rows x 75 columns]
#
#
# DataFrame name: calendar
# Summary of calendar:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6655138 entries, 0 to 6655137
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  float64
#  6   maximum_nights  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 355.4+ MB
# None
#
# First 5 rows of calendar:
#            listing_id        date available    price adjusted_price  \
# 0  553681851841667124  2023-12-25         t  $616.00            NaN
# 1  565466179989073773  2023-12-26         f   $66.00            NaN
# 2  565466179989073773  2023-12-27         t   $66.00            NaN
# 3  565466179989073773  2023-12-28         t   $66.00            NaN
# 4  565466179989073773  2023-12-29         t   $66.00            NaN
#
#    minimum_nights  maximum_nights
# 0            10.0          1125.0
# 1             7.0           365.0
# 2             7.0           365.0
# 3             7.0           365.0
# 4             7.0           365.0
#
#
# DataFrame name: reviews
# Summary of reviews:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522927 entries, 0 to 522926
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     522927 non-null  int64
#  1   id             522927 non-null  int64
#  2   date           522927 non-null  object
#  3   reviewer_id    522927 non-null  int64
#  4   reviewer_name  522925 non-null  object
#  5   comments       522714 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 23.9+ MB
# None
#
# First 5 rows of reviews:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0       57818  3247141  2013-01-03      4203034        Gaurav
# 1       57818  3402974  2013-01-23       252741  Karen & Adam
# 2       57818  3427358  2013-01-28      4539300          Seth
# 3       57818  3483222  2013-02-05      2171166        Claude
# 4       57818  3514314  2013-02-11       435179          Sean
#
#                                             comments
# 0  It was the first trip to Miami for most of us ...
# 1  Wonderful!  Janice was a pleasure to work with...
# 2  Janice was a wonderful host.  Very accommodati...
# 3  Janice is an fine host. She was very prompt on...
# 4  Nice place in an excellent, peaceful and famil...
#
#
# DataFrame name: listings_summary
# Summary of listings_summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18230 entries, 0 to 18229
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              18230 non-null  int64
#  1   name                            18230 non-null  object
#  2   host_id                         18230 non-null  int64
#  3   host_name                       18226 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   18230 non-null  object
#  6   latitude                        18230 non-null  float64
#  7   longitude                       18230 non-null  float64
#  8   room_type                       18230 non-null  object
#  9   price                           17457 non-null  float64
#  10  minimum_nights                  18230 non-null  int64
#  11  number_of_reviews               18230 non-null  int64
#  12  last_review                     14284 non-null  object
#  13  reviews_per_month               14284 non-null  float64
#  14  calculated_host_listings_count  18230 non-null  int64
#  15  availability_365                18230 non-null  int64
#  16  number_of_reviews_ltm           18230 non-null  int64
#  17  license                         1 non-null      object
# dtypes: float64(5), int64(7), object(6)
# memory usage: 2.5+ MB
# None
#
# First 5 rows of listings_summary:
#        id                                               name  host_id  \
# 0   57818  Home in Hollywood · ★4.63 · 2 bedrooms · 2 bed...   275948
# 1   69824  Rental unit in Hallandale · ★4.0 · 2 bedrooms ...   351303
# 2   83449  Rental unit in Dania Beach · ★4.77 · 2 bedroom...   454736
# 3  105411  Rental unit in Southwest Ranches · ★5.0 · 3 be...   532930
# 4  129099  Condo in Hollywood · ★4.29 · 1 bedroom · 2 bed...   637272
#
#                    host_name  neighbourhood_group      neighbourhood  \
# 0                    Von Inc                  NaN          Hollywood
# 1                      Tracy                  NaN   Hallandale Beach
# 2  Jon,  Mary Pop Apartments                  NaN        Dania Beach
# 3                      Sonia                  NaN  Southwest Ranches
# 4                     Bianca                  NaN          Hollywood
#
#    latitude  longitude        room_type  price  minimum_nights  \
# 0  26.01859  -80.12430  Entire home/apt  190.0              32
# 1  25.97641  -80.12052  Entire home/apt  140.0              30
# 2  26.03392  -80.14201  Entire home/apt  127.0               7
# 3  26.04750  -80.36668  Entire home/apt  235.0               4
# 4  25.99414  -80.11814  Entire home/apt  324.0              20
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                 58  2023-03-31               0.43
# 1                  4  2023-06-03               0.12
# 2                 31  2023-12-17               0.21
# 3                  4  2018-03-28               0.03
# 4                 27  2022-07-01               0.18
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               2               214                      1
# 1                               2               281                      2
# 2                              15                 1                      9
# 3                               1               359                      0
# 4                               5               304                      0
#
#   license
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#
#
# DataFrame name: reviews_summary
# Summary of reviews_summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522927 entries, 0 to 522926
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   listing_id  522927 non-null  int64
#  1   date        522927 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 8.0+ MB
# None
#
# First 5 rows of reviews_summary:
#    listing_id        date
# 0       57818  2013-01-03
# 1       57818  2013-01-23
# 2       57818  2013-01-28
# 3       57818  2013-02-05
# 4       57818  2013-02-11
#
#
# DataFrame name: neighbourhoods
# Summary of neighbourhoods:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighbourhood_group  0 non-null      float64
#  1   neighbourhood        34 non-null     object
# dtypes: float64(1), object(1)
# memory usage: 676.0+ bytes
# None
#
# First 5 rows of neighbourhoods:
#    neighbourhood_group             neighbourhood
# 0                  NaN             Coconut Creek
# 1                  NaN               Cooper City
# 2                  NaN             Coral Springs
# 3                  NaN  County Regional Facility
# 4                  NaN               Dania Beach
#
#
# DataFrame name: neighbourhoods_geojson
# Summary of neighbourhoods_geojson:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighbourhood        89 non-null     object
#  1   neighbourhood_group  0 non-null      object
#  2   geometry             89 non-null     geometry
# dtypes: geometry(1), object(2)
# memory usage: 2.2+ KB
# None
#
# First 5 rows of neighbourhoods_geojson:
#      neighbourhood neighbourhood_group  \
# 0   Unincorporated                None
# 1  Fort Lauderdale                None
# 2   Unincorporated                None
# 3   Unincorporated                None
# 4      Dania Beach                None
#
#                                             geometry
# 0  MULTIPOLYGON (((-80.17939 26.32321, -80.18039 ...
# 1  MULTIPOLYGON (((-80.14737 26.19787, -80.14737 ...
# 2  MULTIPOLYGON (((-80.29689 26.35266, -80.29689 ...
# 3  MULTIPOLYGON (((-80.22163 26.33268, -80.22276 ...
# 4  MULTIPOLYGON (((-80.20522 26.04778, -80.20515 ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Questions from Professor
#
# The data is for one day, avaliable at one time. With that, there is not a ton of data. One ask is to clean the data for processing
# - cluter the listings: categories of listings. There are a lot of features. Show the results, and compare models.
# - do the same for the hosts. Number of properties the house has.
# - You can apply certain rules.
#
# - Each listing comes with a price. Most of the time these prices are constant. Find out the top 3 factors for price.
#
# 4. This does not have a definite answer. Let us say you live in a 3 bedroom 2 bathroom house. We can use that as an estimate of the size of the proeprty. And you have the flexibility to put it anywhere in this map. Where do you want to be?
#
# BONUS: what else can you do if you are the investor to increase expected revenue?
#
# QUESTIONS:
# - how many reports? There are different rules
#
# - Connect extrsa data like house prices.
#
# - There is a particular goal. If you can create a good connection, that would be good.
#
# - For question 4) do we seperate the value per bedroom. 70% was whole house, 20% private bedroom.
#  IT is just up to us, we can choose what works best to get most revenue.
#
# - So we assume we have a single family home. Maximize the daily value per bedroom. The reason why is that it is normalized. If you divide that by 10, maybe the 1 bedroom condo would give better revenue. This is just a way to normalize revenue.
#
# ## How is it going to be graded?
#
# This is complicated, it is suggested as a group. The grading is based on the group and individual performance. group of 4 people, everyone submits their own report.
#
# Divide the project into a few parts. In practice, it will all be a team effort.
#
# If you have two team members, 2 and 3. and another do 4 and 5.
#
# Is there specific format for project report, same as the midterm.
# Jupyter Notebook. Presentations.
#
# Submit your own individual report. Ideally, it will only need to cover your part.
#
# For the presentaiton for the slides, you can have a whole presentation. Do it as a group. How many slides should be per group member.
#
# - A nice thing to do is to have each model member do different models.
#
# - Minutes to present (TBD).
#
# - When you upload files with submissions: make sure you have first and last name.

# %%
# Adjust display settings to show all columns
pd.set_option('display.max_columns', None)
listings.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   57818   https://www.airbnb.com/rooms/57818  20231225202534   2023-12-26
# 1   69824   https://www.airbnb.com/rooms/69824  20231225202534   2023-12-26
# 2   83449   https://www.airbnb.com/rooms/83449  20231225202534   2023-12-27
# 3  105411  https://www.airbnb.com/rooms/105411  20231225202534   2023-12-26
# 4  129099  https://www.airbnb.com/rooms/129099  20231225202534   2023-12-26
#
#         source                                               name  \
# 0  city scrape  Home in Hollywood · ★4.63 · 2 bedrooms · 2 bed...
# 1  city scrape  Rental unit in Hallandale · ★4.0 · 2 bedrooms ...
# 2  city scrape  Rental unit in Dania Beach · ★4.77 · 2 bedroom...
# 3  city scrape  Rental unit in Southwest Ranches · ★5.0 · 3 be...
# 4  city scrape  Condo in Hollywood · ★4.29 · 1 bedroom · 2 bed...
#
#    description                              neighborhood_overview  \
# 0          NaN  Check-in window<br />After 3:00 PM<br />Edit<b...
# 1          NaN                                                NaN
# 2          NaN  Residential neighborhood, less than 2 miles to...
# 3          NaN  Very close to I75, one of the main highways. Y...
# 4          NaN                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...   275948
# 1  https://a0.muscache.com/pictures/443102/f6b94e...   351303
# 2  https://a0.muscache.com/pictures/8c21bda0-5194...   454736
# 3  https://a0.muscache.com/pictures/787317/2cc18e...   532930
# 4  https://a0.muscache.com/pictures/828393/baabb6...   637272
#
#                                    host_url                  host_name  \
# 0  https://www.airbnb.com/users/show/275948                    Von Inc
# 1  https://www.airbnb.com/users/show/351303                      Tracy
# 2  https://www.airbnb.com/users/show/454736  Jon,  Mary Pop Apartments
# 3  https://www.airbnb.com/users/show/532930                      Sonia
# 4  https://www.airbnb.com/users/show/637272                     Bianca
#
#    host_since            host_location  \
# 0  2010-11-01            Hollywood, FL
# 1  2011-01-17        Silver Spring, MD
# 2  2011-03-21          Dania Beach, FL
# 3  2011-04-25    Southwest Ranches, FL
# 4  2011-05-28  Buenos Aires, Argentina
#
#                                           host_about  host_response_time  \
# 0  I love my house...the neighbors are wonderful,...      within an hour
# 1                                                NaN      within an hour
# 2   LOCATION,LOCATION,LOCATION, NUMBER 1 ACCOMMOD...      within an hour
# 3  We are from Southwest ranches and we have a sm...      within an hour
# 4  Hope you have a nice time in our apartments :)...  a few days or more
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  96%                 t
# 1               100%                  50%                 f
# 2               100%                  97%                 f
# 3                80%                  57%                 f
# 4                36%                  18%                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/1f267...
# 1  https://a0.muscache.com/im/users/351303/profil...
# 2  https://a0.muscache.com/im/users/454736/profil...
# 3  https://a0.muscache.com/im/users/532930/profil...
# 4  https://a0.muscache.com/im/users/637272/profil...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/1f267...                NaN
# 1  https://a0.muscache.com/im/users/351303/profil...                NaN
# 2  https://a0.muscache.com/im/users/454736/profil...                NaN
# 3  https://a0.muscache.com/im/users/532930/profil...                NaN
# 4  https://a0.muscache.com/im/users/637272/profil...  Sunny Isles Beach
#
#    host_listings_count  host_total_listings_count  \
# 0                  3.0                        3.0
# 1                  3.0                        5.0
# 2                 17.0                       20.0
# 3                  3.0                        3.0
# 4                  9.0                       19.0
#
#                  host_verifications host_has_profile_pic  \
# 0                ['email', 'phone']                    t
# 1                ['email', 'phone']                    t
# 2                ['email', 'phone']                    t
# 3  ['email', 'phone', 'work_email']                    t
# 4                ['email', 'phone']                    t
#
#   host_identity_verified                              neighbourhood  \
# 0                      t          Hollywood, Florida, United States
# 1                      t                                        NaN
# 2                      t        Dania Beach, Florida, United States
# 3                      t  Southwest Ranches, Florida, United States
# 4                      t                                        NaN
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed  latitude  longitude  \
# 0              Hollywood                           NaN  26.01859  -80.12430
# 1       Hallandale Beach                           NaN  25.97641  -80.12052
# 2            Dania Beach                           NaN  26.03392  -80.14201
# 3      Southwest Ranches                           NaN  26.04750  -80.36668
# 4              Hollywood                           NaN  25.99414  -80.11814
#
#         property_type        room_type  accommodates  bathrooms  \
# 0         Entire home  Entire home/apt             4        NaN
# 1  Entire rental unit  Entire home/apt             6        NaN
# 2  Entire rental unit  Entire home/apt             5        NaN
# 3  Entire rental unit  Entire home/apt             5        NaN
# 4        Entire condo  Entire home/apt             5        NaN
#
#   bathrooms_text  bedrooms  beds amenities    price  minimum_nights  \
# 0         1 bath       NaN   2.0        []  $190.00              32
# 1        2 baths       NaN   4.0        []  $140.00              30
# 2         1 bath       NaN   3.0        []  $127.00               7
# 3        2 baths       NaN   3.0        []  $235.00               4
# 4      1.5 baths       NaN   2.0        []  $324.00              20
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0            1125                       1                      32
# 1             365                      30                      30
# 2             180                       7                       7
# 3             180                       4                       4
# 4             365                      20                      20
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                    1125                    1125                    31.9
# 1                     365                     365                    30.0
# 2                     180                     180                     7.0
# 3                     180                     180                     4.0
# 4                     365                     365                    20.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                  1125.0               NaN                t                2
# 1                   365.0               NaN                t               19
# 2                   180.0               NaN                t                0
# 3                   180.0               NaN                t               24
# 4                   365.0               NaN                t                6
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0                2               10               214            2023-12-26
# 1               19               19               281            2023-12-26
# 2                1                1                 1            2023-12-27
# 3               54               84               359            2023-12-26
# 4               18               29               304            2023-12-26
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                 58                      1                       0
# 1                  4                      2                       0
# 2                 31                      9                       1
# 3                  4                      0                       0
# 4                 27                      0                       0
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2013-01-03  2023-03-31                  4.63                    4.69
# 1   2021-03-27  2023-06-03                  4.00                    4.50
# 2   2011-11-01  2023-12-17                  4.77                    4.87
# 3   2012-08-06  2018-03-28                  5.00                    5.00
# 4   2011-08-23  2022-07-01                  4.29                    4.42
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.61                   5.00
# 1                       4.00                   4.75
# 2                       4.84                   4.94
# 3                       5.00                   5.00
# 4                       4.24                   4.44
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.97                    4.88                 4.71
# 1                         4.75                    5.00                 4.50
# 2                         4.90                    4.81                 4.87
# 3                         5.00                    4.25                 5.00
# 4                         4.32                    4.54                 4.08
#
#   license instant_bookable  calculated_host_listings_count  \
# 0     NaN                f                               2
# 1     NaN                f                               2
# 2     NaN                f                              15
# 3     NaN                f                               1
# 4     NaN                f                               5
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            2
# 1                                            2
# 2                                           15
# 3                                            1
# 4                                            5
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.43
# 1                                            0               0.12
# 2                                            0               0.21
# 3                                            0               0.03
# 4                                            0               0.18

# %% [markdown]
# We are going to remove obviously unnessessary columns:

# %%
# Remove unnecessary columns
columns_to_remove = [
    "listing_url", "scrape_id", "last_scraped", "source", "description",
    "neighborhood_overview", "picture_url", "host_url", "host_about",
    "host_thumbnail_url", "host_picture_url", "host_neighbourhood",
    "neighbourhood", "neighbourhood_group_cleansed", "bathrooms", 
    "bedrooms", "amenities", "calendar_updated", "calendar_last_scraped",
    "license", "instant_bookable", "host_verifications", "property_type", "name", "minimum_minimum_nights", "maximum_minimum_nights", "minimum_maximum_nights", "maximum_maximum_nights",
    "minimum_nights_avg_ntm", "maximum_nights_avg_ntm", "calculated_host_listings_count", "calculated_host_listings_count_entire_homes", "calculated_host_listings_count_private_rooms", "calculated_host_listings_count_shared_rooms"
]

listings_cleaned = listings.drop(columns=columns_to_remove)

# Clean the price column by removing dollar signs and converting to numeric
listings_cleaned['price'] = listings_cleaned['price'].replace('[\$,]', '', regex=True).astype(float)

# Extract numeric values from bathrooms_text and create a new bathrooms column
listings_cleaned['bathrooms'] = listings_cleaned['bathrooms_text'].str.extract('(\d+(\.\d+)?)')[0].astype(float)

# Drop the old bathrooms_text column
listings_cleaned.drop(columns=['bathrooms_text'], inplace=True)

# Calculate vacancy and booking rates
listings_cleaned['vacancy_rate_30'] = listings_cleaned['availability_30'] / 30
listings_cleaned['vacancy_rate_60'] = listings_cleaned['availability_60'] / 60
listings_cleaned['vacancy_rate_90'] = listings_cleaned['availability_90'] / 90
listings_cleaned['vacancy_rate_365'] = listings_cleaned['availability_365'] / 365


# Display the first 5 rows of the cleaned dataframe
listings_cleaned.head(10)
# Out:
#        id  host_id                  host_name  host_since  \
# 0   57818   275948                    Von Inc  2010-11-01
# 1   69824   351303                      Tracy  2011-01-17
# 2   83449   454736  Jon,  Mary Pop Apartments  2011-03-21
# 3  105411   532930                      Sonia  2011-04-25
# 4  129099   637272                     Bianca  2011-05-28
# 5  191160   924482                        Dan  2011-08-05
# 6  216046   964836                       Gary  2011-08-13
# 7  217990   637272                     Bianca  2011-05-28
# 8  241944   454736  Jon,  Mary Pop Apartments  2011-03-21
# 9  256386  1304156                    Nicolas  2011-10-17
#
#              host_location  host_response_time host_response_rate  \
# 0            Hollywood, FL      within an hour               100%
# 1        Silver Spring, MD      within an hour               100%
# 2          Dania Beach, FL      within an hour               100%
# 3    Southwest Ranches, FL      within an hour                80%
# 4  Buenos Aires, Argentina  a few days or more                36%
# 5      Fort Lauderdale, FL                 NaN                NaN
# 6            Hollywood, FL      within an hour               100%
# 7  Buenos Aires, Argentina  a few days or more                36%
# 8          Dania Beach, FL      within an hour               100%
# 9    Sunny Isles Beach, FL      within an hour               100%
#
#   host_acceptance_rate host_is_superhost  host_listings_count  \
# 0                  96%                 t                  3.0
# 1                  50%                 f                  3.0
# 2                  97%                 f                 17.0
# 3                  57%                 f                  3.0
# 4                  18%                 f                  9.0
# 5                  NaN                 f                  2.0
# 6                  93%                 t                  1.0
# 7                  18%                 f                  9.0
# 8                  97%                 f                 17.0
# 9                  99%                 t                  7.0
#
#    host_total_listings_count host_has_profile_pic host_identity_verified  \
# 0                        3.0                    t                      t
# 1                        5.0                    t                      t
# 2                       20.0                    t                      t
# 3                        3.0                    t                      t
# 4                       19.0                    t                      t
# 5                        3.0                    t                      f
# 6                        2.0                    t                      t
# 7                       19.0                    t                      t
# 8                       20.0                    t                      t
# 9                       10.0                    t                      t
#
#   neighbourhood_cleansed  latitude  longitude        room_type  accommodates  \
# 0              Hollywood  26.01859  -80.12430  Entire home/apt             4
# 1       Hallandale Beach  25.97641  -80.12052  Entire home/apt             6
# 2            Dania Beach  26.03392  -80.14201  Entire home/apt             5
# 3      Southwest Ranches  26.04750  -80.36668  Entire home/apt             5
# 4              Hollywood  25.99414  -80.11814  Entire home/apt             5
# 5        Deerfield Beach  26.30707  -80.07793  Entire home/apt             4
# 6              Hollywood  26.00770  -80.19722  Entire home/apt            10
# 7              Hollywood  25.99398  -80.11677  Entire home/apt             5
# 8            Dania Beach  26.03392  -80.14201  Entire home/apt             3
# 9              Hollywood  26.02584  -80.14191  Entire home/apt             4
#
#    beds  price  minimum_nights  maximum_nights has_availability  \
# 0   2.0  190.0              32            1125                t
# 1   4.0  140.0              30             365                t
# 2   3.0  127.0               7             180                t
# 3   3.0  235.0               4             180                t
# 4   2.0  324.0              20             365                t
# 5   2.0  119.0               2             180                t
# 6   7.0  295.0               3              21                t
# 7   1.0  250.0              10             365                t
# 8   2.0   89.0               7             175                t
# 9   2.0  120.0               2             365                t
#
#    availability_30  availability_60  availability_90  availability_365  \
# 0                2                2               10               214
# 1               19               19               19               281
# 2                0                1                1                 1
# 3               24               54               84               359
# 4                6               18               29               304
# 5                1                1                1                86
# 6               11               18               29               279
# 7               19               49               79               354
# 8               17               17               17                17
# 9               17               35               54               327
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                 58                      1                       0
# 1                  4                      2                       0
# 2                 31                      9                       1
# 3                  4                      0                       0
# 4                 27                      0                       0
# 5                 25                      0                       0
# 6                106                     11                       0
# 7                 18                      0                       0
# 8                 13                      3                       1
# 9                247                     27                       4
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2013-01-03  2023-03-31                  4.63                    4.69
# 1   2021-03-27  2023-06-03                  4.00                    4.50
# 2   2011-11-01  2023-12-17                  4.77                    4.87
# 3   2012-08-06  2018-03-28                  5.00                    5.00
# 4   2011-08-23  2022-07-01                  4.29                    4.42
# 5   2012-01-04  2019-11-08                  4.25                    4.39
# 6   2012-01-02  2023-11-21                  4.81                    4.79
# 7   2011-11-21  2018-03-19                  4.93                    4.88
# 8   2012-07-28  2023-12-02                  4.58                    4.54
# 9   2012-01-02  2023-12-18                  4.84                    4.88
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.61                   5.00
# 1                       4.00                   4.75
# 2                       4.84                   4.94
# 3                       5.00                   5.00
# 4                       4.24                   4.44
# 5                       4.46                   4.83
# 6                       4.81                   4.92
# 7                       4.81                   5.00
# 8                       4.54                   4.85
# 9                       4.87                   4.93
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.97                    4.88                 4.71
# 1                         4.75                    5.00                 4.50
# 2                         4.90                    4.81                 4.87
# 3                         5.00                    4.25                 5.00
# 4                         4.32                    4.54                 4.08
# 5                         4.87                    4.87                 4.43
# 6                         4.77                    4.77                 4.77
# 7                         5.00                    4.88                 4.81
# 8                         4.92                    4.54                 4.54
# 9                         4.91                    4.67                 4.79
#
#    reviews_per_month  bathrooms  vacancy_rate_30  vacancy_rate_60  \
# 0               0.43        1.0         0.066667         0.033333
# 1               0.12        2.0         0.633333         0.316667
# 2               0.21        1.0         0.000000         0.016667
# 3               0.03        2.0         0.800000         0.900000
# 4               0.18        1.5         0.200000         0.300000
# 5               0.17        1.0         0.033333         0.016667
# 6               0.73        3.0         0.366667         0.300000
# 7               0.12        1.5         0.633333         0.816667
# 8               0.09        1.0         0.566667         0.283333
# 9               1.69        1.0         0.566667         0.583333
#
#    vacancy_rate_90  vacancy_rate_365
# 0         0.111111          0.586301
# 1         0.211111          0.769863
# 2         0.011111          0.002740
# 3         0.933333          0.983562
# 4         0.322222          0.832877
# 5         0.011111          0.235616
# 6         0.322222          0.764384
# 7         0.877778          0.969863
# 8         0.188889          0.046575
# 9         0.600000          0.895890

# %% [markdown]
# # Adding Reviews data
#
# To create a new column with sentiment scores for the reviews, we can use a sentiment analysis library such as TextBlob or VADER. These libraries provide tools to analyze the sentiment of text and return a score. Here’s how you can do it:

# %%
# %pip install -q textblob vaderSentiment

from textblob import TextBlob

# Calculate sentiment scores for reviews
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

reviews['sentiment'] = reviews['comments'].apply(lambda x: get_sentiment(str(x)))

# Merge sentiment scores with listings data
sentiment_by_listing = reviews.groupby('listing_id')['sentiment'].mean().reset_index()
listings_cleaned = listings_cleaned.merge(sentiment_by_listing, left_on='id', right_on='listing_id', how='left')

reviews.head()
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0       57818  3247141  2013-01-03      4203034        Gaurav
# 1       57818  3402974  2013-01-23       252741  Karen & Adam
# 2       57818  3427358  2013-01-28      4539300          Seth
# 3       57818  3483222  2013-02-05      2171166        Claude
# 4       57818  3514314  2013-02-11       435179          Sean
#
#                                             comments  sentiment
# 0  It was the first trip to Miami for most of us ...   0.332544
# 1  Wonderful!  Janice was a pleasure to work with...   0.288095
# 2  Janice was a wonderful host.  Very accommodati...   0.267857
# 3  Janice is an fine host. She was very prompt on...   0.381636
# 4  Nice place in an excellent, peaceful and famil...   0.494048

# %%
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Initialize VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Calculate sentiment scores using TextBlob and VADER
def get_sentiment(text):
    return TextBlob(text).sentiment.polarity

def get_vader_sentiment(text):
    return analyzer.polarity_scores(text)

reviews['polarity'] = reviews['comments'].apply(lambda x: get_sentiment(str(x)))
vader_sentiments = reviews['comments'].apply(lambda x: get_vader_sentiment(str(x)))
vader_df = pd.DataFrame(vader_sentiments.tolist())
reviews = pd.concat([reviews, vader_df], axis=1)

# Merge sentiment scores with listings data
sentiment_by_listing = reviews.groupby('listing_id').agg({
    'polarity': 'mean',
    'compound': 'mean'
}).reset_index()

# Merge the sentiment metrics with listings_cleaned to create reviews_listings
reviews_listings = listings_cleaned.merge(sentiment_by_listing, left_on='id', right_on='listing_id', how='left')

# Display the first few rows of reviews_listings
print(reviews_listings.head())

# Calculate the correlation matrix for only numeric columns
correlation_matrix = reviews_listings[['price', 'polarity', 'compound']].corr()

# Plot the heatmap for the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# Display the correlation matrix for price with other numerical columns as a bar plot
plt.figure(figsize=(8, 6))
correlation_matrix['price'].drop('price').sort_values().plot(kind='barh', color='blue')
plt.title('Correlation with Price')
plt.xlabel('Correlation Coefficient')
plt.ylabel('Features')
plt.show()
# Out:
#        id  host_id                  host_name  host_since  \
# 0   57818   275948                    Von Inc  2010-11-01
# 1   69824   351303                      Tracy  2011-01-17
# 2   83449   454736  Jon,  Mary Pop Apartments  2011-03-21
# 3  105411   532930                      Sonia  2011-04-25
# 4  129099   637272                     Bianca  2011-05-28
#
#              host_location  host_response_time host_response_rate  \
# 0            Hollywood, FL      within an hour               100%
# 1        Silver Spring, MD      within an hour               100%
# 2          Dania Beach, FL      within an hour               100%
# 3    Southwest Ranches, FL      within an hour                80%
# 4  Buenos Aires, Argentina  a few days or more                36%
#
#   host_acceptance_rate host_is_superhost  host_listings_count  \
# 0                  96%                 t                  3.0
# 1                  50%                 f                  3.0
# 2                  97%                 f                 17.0
# 3                  57%                 f                  3.0
# 4                  18%                 f                  9.0
#
#    host_total_listings_count host_has_profile_pic host_identity_verified  \
# 0                        3.0                    t                      t
# 1                        5.0                    t                      t
# 2                       20.0                    t                      t
# 3                        3.0                    t                      t
# 4                       19.0                    t                      t
#
#   neighbourhood_cleansed  latitude  longitude        room_type  accommodates  \
# 0              Hollywood  26.01859  -80.12430  Entire home/apt             4
# 1       Hallandale Beach  25.97641  -80.12052  Entire home/apt             6
# 2            Dania Beach  26.03392  -80.14201  Entire home/apt             5
# 3      Southwest Ranches  26.04750  -80.36668  Entire home/apt             5
# 4              Hollywood  25.99414  -80.11814  Entire home/apt             5
#
#    beds  price  minimum_nights  maximum_nights has_availability  \
# 0   2.0  190.0              32            1125                t
# 1   4.0  140.0              30             365                t
# 2   3.0  127.0               7             180                t
# 3   3.0  235.0               4             180                t
# 4   2.0  324.0              20             365                t
#
#    availability_30  availability_60  availability_90  availability_365  \
# 0                2                2               10               214
# 1               19               19               19               281
# 2                0                1                1                 1
# 3               24               54               84               359
# 4                6               18               29               304
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                 58                      1                       0
# 1                  4                      2                       0
# 2                 31                      9                       1
# 3                  4                      0                       0
# 4                 27                      0                       0
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2013-01-03  2023-03-31                  4.63                    4.69
# 1   2021-03-27  2023-06-03                  4.00                    4.50
# 2   2011-11-01  2023-12-17                  4.77                    4.87
# 3   2012-08-06  2018-03-28                  5.00                    5.00
# 4   2011-08-23  2022-07-01                  4.29                    4.42
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.61                   5.00
# 1                       4.00                   4.75
# 2                       4.84                   4.94
# 3                       5.00                   5.00
# 4                       4.24                   4.44
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.97                    4.88                 4.71
# 1                         4.75                    5.00                 4.50
# 2                         4.90                    4.81                 4.87
# 3                         5.00                    4.25                 5.00
# 4                         4.32                    4.54                 4.08
#
#    reviews_per_month  bathrooms  vacancy_rate_30  vacancy_rate_60  \
# 0               0.43        1.0         0.066667         0.033333
# 1               0.12        2.0         0.633333         0.316667
# 2               0.21        1.0         0.000000         0.016667
# 3               0.03        2.0         0.800000         0.900000
# 4               0.18        1.5         0.200000         0.300000
#
#    vacancy_rate_90  vacancy_rate_365  listing_id_x  sentiment  listing_id_y  \
# 0         0.111111          0.586301       57818.0   0.374216       57818.0
# 1         0.211111          0.769863       69824.0   0.190601       69824.0
# 2         0.011111          0.002740       83449.0   0.392146       83449.0
# 3         0.933333          0.983562      105411.0   0.184327      105411.0
# 4         0.322222          0.832877      129099.0   0.374725      129099.0
#
#    polarity  compound
# 0  0.374216  0.789202
# 1  0.190601  0.445600
# 2  0.392146  0.624126
# 3  0.184327  0.696325
# 4  0.374725  0.537548

# %%
# Calculate the correlation matrix for only numeric columns
correlation_matrix = listings_cleaned.select_dtypes(include='number').corr()

# Display the correlation matrix for price with other numerical columns
print(correlation_matrix['price'])
# Out:
# id                                              0.001230
# host_id                                        -0.000203
# host_listings_count                            -0.003733
# host_total_listings_count                      -0.002942
# latitude                                       -0.016896
# longitude                                       0.042550
# accommodates                                    0.242030
# beds                                            0.219146
# price                                           1.000000
# minimum_nights                                 -0.015488
# maximum_nights                                  0.035181
# minimum_minimum_nights                         -0.015457
# maximum_minimum_nights                         -0.013722
# minimum_maximum_nights                          0.002212
# maximum_maximum_nights                          0.002582
# minimum_nights_avg_ntm                         -0.015974
# maximum_nights_avg_ntm                          0.002582
# availability_30                                 0.051428
# availability_60                                 0.053076
# availability_90                                 0.052001
# availability_365                                0.062235
# number_of_reviews                              -0.033421
# number_of_reviews_ltm                          -0.037035
# number_of_reviews_l30d                         -0.044152
# review_scores_rating                            0.033697
# review_scores_accuracy                          0.029167
# review_scores_cleanliness                       0.028909
# review_scores_checkin                           0.020037
# review_scores_communication                     0.020489
# review_scores_location                          0.037149
# review_scores_value                             0.025246
# calculated_host_listings_count                 -0.009196
# calculated_host_listings_count_entire_homes    -0.009665
# calculated_host_listings_count_private_rooms    0.005218
# calculated_host_listings_count_shared_rooms    -0.021113
# reviews_per_month                              -0.032207
# bathrooms                                       0.278086
# Name: price, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix for only numeric columns
correlation_matrix = listings_cleaned.select_dtypes(include='number').corr()

# Plot the heatmap for the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# Display the correlation matrix for price with other numerical columns as a bar plot
plt.figure(figsize=(8, 6))
correlation_matrix['price'].drop('price').sort_values().plot(kind='barh', color='blue')
plt.title('Correlation with Price')
plt.xlabel('Correlation Coefficient')
plt.ylabel('Features')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# Fill missing values
listings_cleaned['bathrooms'].fillna(listings_cleaned['bathrooms'].mean(), inplace=True)
listings_cleaned['beds'].fillna(listings_cleaned['beds'].mean(), inplace=True)
listings_cleaned['price'].fillna(listings_cleaned['price'].mean(), inplace=True)
listings_cleaned['availability_30'].fillna(listings_cleaned['availability_30'].mean(), inplace=True)
listings_cleaned['availability_60'].fillna(listings_cleaned['availability_60'].mean(), inplace=True)
listings_cleaned['availability_90'].fillna(listings_cleaned['availability_90'].mean(), inplace=True)
listings_cleaned['availability_365'].fillna(listings_cleaned['availability_365'].mean(), inplace=True)
listings_cleaned['review_scores_rating'].fillna(listings_cleaned['review_scores_rating'].mean(), inplace=True)
listings_cleaned['reviews_per_month'].fillna(listings_cleaned['reviews_per_month'].mean(), inplace=True)

# Select relevant features for clustering
features = ['price', 'vacancy_rate_365']

# Standardize the features
scaler = StandardScaler()
listings_scaled = scaler.fit_transform(listings_cleaned[features])

# Determine the optimal number of clusters using the elbow method
inertia = []
for n in range(1, 11):
    kmeans = KMeans(n_clusters=n, random_state=42)
    kmeans.fit(listings_scaled)
    inertia.append(kmeans.inertia_)

# Plot the elbow curve
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), inertia, marker='o')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# Choose the optimal number of clusters and fit KMeans
optimal_clusters = 4  # Assuming 4 is the optimal number from the elbow plot
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
listings_cleaned['listing_cluster'] = kmeans.fit_predict(listings_scaled)

# Display the first few rows with the cluster labels
print(listings_cleaned.head())

# Plot the clusters by price and vacancy_rate_365
plt.figure(figsize=(12, 8))
sns.scatterplot(
    x='price', y='vacancy_rate_365', hue='listing_cluster',
    palette=sns.color_palette('hsv', optimal_clusters), data=listings_cleaned
)
plt.title('Clusters of Listings by Price and Vacancy Rate')
plt.xlabel('Price')
plt.ylabel('Vacancy Rate (365 days)')
plt.show()
# Out:
# /var/folders/7v/1qhzk08s1bb2n8sj9h5y5l5h0000gp/T/ipykernel_3122/4050136896.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   listings_cleaned['bathrooms'].fillna(listings_cleaned['bathrooms'].mean(), inplace=True)
# /var/folders/7v/1qhzk08s1bb2n8sj9h5y5l5h0000gp/T/ipykernel_3122/4050136896.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   listings_cleaned['beds'].fillna(listings_cleaned['beds'].mean(), inplace=True)
# /var/folders/7v/1qhzk08s1bb2n8sj9h5y5l5h0000gp/T/ipykernel_3122/4050136896.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   listings_cleaned['price'].fillna(listings_cleaned['price'].mean(), inplace=True)
# /var/folders/7v/1qhzk08s1bb2n8sj9h5y5l5h0000gp/T/ipykernel_3122/4050136896.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   listings_cleaned['availability_30'].fillna(listings_cleaned['availability_30'].mean(), inplace=True)
# /var/folders/7v/1qhzk08s1bb2n8sj9h5y5l5h0000gp/T/ipykernel_3122/4050136896.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   listings_cleaned['availability_60'].fillna(listings_cleaned['availability_60'].mean(), inplace=True)
# /var/folders/7v/1qhzk08s1bb2n8sj9h5y5l5h0000gp/T/ipykernel_3122/4050136896.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   listings_cleaned['availability_90'].fillna(listings_cleaned['availability_90'].mean(), inplace=True)
# /var/folders/7v/1qhzk08s1bb2n8sj9h5y5l5h0000gp/T/ipykernel_3122/4050136896.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   listings_cleaned['availability_365'].fillna(listings_cleaned['availability_365'].mean(), inplace=True)
# /var/folders/7v/1qhzk08s1bb2n8sj9h5y5l5h0000gp/T/ipykernel_3122/4050136896.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   listings_cleaned['review_scores_rating'].fillna(listings_cleaned['review_scores_rating'].mean(), inplace=True)
# /var/folders/7v/1qhzk08s1bb2n8sj9h5y5l5h0000gp/T/ipykernel_3122/4050136896.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   listings_cleaned['reviews_per_month'].fillna(listings_cleaned['reviews_per_month'].mean(), inplace=True)
#        id  host_id                  host_name  host_since  \
# 0   57818   275948                    Von Inc  2010-11-01
# 1   69824   351303                      Tracy  2011-01-17
# 2   83449   454736  Jon,  Mary Pop Apartments  2011-03-21
# 3  105411   532930                      Sonia  2011-04-25
# 4  129099   637272                     Bianca  2011-05-28
#
#              host_location  host_response_time host_response_rate  \
# 0            Hollywood, FL      within an hour               100%
# 1        Silver Spring, MD      within an hour               100%
# 2          Dania Beach, FL      within an hour               100%
# 3    Southwest Ranches, FL      within an hour                80%
# 4  Buenos Aires, Argentina  a few days or more                36%
#
#   host_acceptance_rate host_is_superhost  host_listings_count  \
# 0                  96%                 t                  3.0
# 1                  50%                 f                  3.0
# 2                  97%                 f                 17.0
# 3                  57%                 f                  3.0
# 4                  18%                 f                  9.0
#
#    host_total_listings_count host_has_profile_pic host_identity_verified  \
# 0                        3.0                    t                      t
# 1                        5.0                    t                      t
# 2                       20.0                    t                      t
# 3                        3.0                    t                      t
# 4                       19.0                    t                      t
#
#   neighbourhood_cleansed  latitude  longitude        room_type  accommodates  \
# 0              Hollywood  26.01859  -80.12430  Entire home/apt             4
# 1       Hallandale Beach  25.97641  -80.12052  Entire home/apt             6
# 2            Dania Beach  26.03392  -80.14201  Entire home/apt             5
# 3      Southwest Ranches  26.04750  -80.36668  Entire home/apt             5
# 4              Hollywood  25.99414  -80.11814  Entire home/apt             5
#
#    beds  price  minimum_nights  maximum_nights has_availability  \
# 0   2.0  190.0              32            1125                t
# 1   4.0  140.0              30             365                t
# 2   3.0  127.0               7             180                t
# 3   3.0  235.0               4             180                t
# 4   2.0  324.0              20             365                t
#
#    availability_30  availability_60  availability_90  availability_365  \
# 0                2                2               10               214
# 1               19               19               19               281
# 2                0                1                1                 1
# 3               24               54               84               359
# 4                6               18               29               304
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                 58                      1                       0
# 1                  4                      2                       0
# 2                 31                      9                       1
# 3                  4                      0                       0
# 4                 27                      0                       0
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2013-01-03  2023-03-31                  4.63                    4.69
# 1   2021-03-27  2023-06-03                  4.00                    4.50
# 2   2011-11-01  2023-12-17                  4.77                    4.87
# 3   2012-08-06  2018-03-28                  5.00                    5.00
# 4   2011-08-23  2022-07-01                  4.29                    4.42
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.61                   5.00
# 1                       4.00                   4.75
# 2                       4.84                   4.94
# 3                       5.00                   5.00
# 4                       4.24                   4.44
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.97                    4.88                 4.71
# 1                         4.75                    5.00                 4.50
# 2                         4.90                    4.81                 4.87
# 3                         5.00                    4.25                 5.00
# 4                         4.32                    4.54                 4.08
#
#    reviews_per_month  bathrooms  vacancy_rate_30  vacancy_rate_60  \
# 0               0.43        1.0         0.066667         0.033333
# 1               0.12        2.0         0.633333         0.316667
# 2               0.21        1.0         0.000000         0.016667
# 3               0.03        2.0         0.800000         0.900000
# 4               0.18        1.5         0.200000         0.300000
#
#    vacancy_rate_90  vacancy_rate_365  listing_cluster  host_cluster
# 0         0.111111          0.586301                1             1
# 1         0.211111          0.769863                3             1
# 2         0.011111          0.002740                0             2
# 3         0.933333          0.983562                3             0
# 4         0.322222          0.832877                3             0

# %%
# Aggregate features by host
host_features = listings_cleaned.groupby('host_id').agg({
    'price': 'mean',
    'vacancy_rate_365': 'mean',
    'listing_cluster': 'mean'  # Average cluster label
}).reset_index()

# Standardize the host features
scaler = StandardScaler()
host_scaled = scaler.fit_transform(host_features.drop(columns=['host_id']))

# Determine the optimal number of clusters for hosts using the elbow method
host_inertia = []
for n in range(1, 11):
    kmeans = KMeans(n_clusters=n, random_state=42)
    kmeans.fit(host_scaled)
    host_inertia.append(kmeans.inertia_)

# Plot the elbow curve for hosts
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), host_inertia, marker='o')
plt.title('Elbow Method for Optimal Number of Host Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# Choose the optimal number of clusters for hosts and fit KMeans
optimal_host_clusters = 3  # Assuming 3 is the optimal number from the elbow plot
kmeans = KMeans(n_clusters=optimal_host_clusters, random_state=42)
host_features['host_cluster'] = kmeans.fit_predict(host_scaled)

# Drop any existing host_cluster column in listings_cleaned
if 'host_cluster' in listings_cleaned.columns:
    listings_cleaned = listings_cleaned.drop(columns=['host_cluster'])

# Merge the host cluster labels back to the listings_cleaned dataframe
listings_cleaned = listings_cleaned.merge(host_features[['host_id', 'host_cluster']], on='host_id', how='left')

# Display the first few rows with the host cluster labels
print(listings_cleaned.head())

# Plot the host clusters by price and vacancy_rate_365 with a limit on the price axis
plt.figure(figsize=(12, 8))
sns.scatterplot(
    x='price', y='vacancy_rate_365', hue='host_cluster',
    palette=sns.color_palette('cool', optimal_host_clusters), data=listings_cleaned
)
plt.title('Clusters of Hosts by Price and Vacancy Rate')
plt.xlabel('Price')
plt.ylabel('Vacancy Rate (365 days)')
plt.xlim(0, 20000)  # Set the x-axis limit to 20,000
plt.show()
# Out:
#        id  host_id                  host_name  host_since  \
# 0   57818   275948                    Von Inc  2010-11-01
# 1   69824   351303                      Tracy  2011-01-17
# 2   83449   454736  Jon,  Mary Pop Apartments  2011-03-21
# 3  105411   532930                      Sonia  2011-04-25
# 4  129099   637272                     Bianca  2011-05-28
#
#              host_location  host_response_time host_response_rate  \
# 0            Hollywood, FL      within an hour               100%
# 1        Silver Spring, MD      within an hour               100%
# 2          Dania Beach, FL      within an hour               100%
# 3    Southwest Ranches, FL      within an hour                80%
# 4  Buenos Aires, Argentina  a few days or more                36%
#
#   host_acceptance_rate host_is_superhost  host_listings_count  \
# 0                  96%                 t                  3.0
# 1                  50%                 f                  3.0
# 2                  97%                 f                 17.0
# 3                  57%                 f                  3.0
# 4                  18%                 f                  9.0
#
#    host_total_listings_count host_has_profile_pic host_identity_verified  \
# 0                        3.0                    t                      t
# 1                        5.0                    t                      t
# 2                       20.0                    t                      t
# 3                        3.0                    t                      t
# 4                       19.0                    t                      t
#
#   neighbourhood_cleansed  latitude  longitude        room_type  accommodates  \
# 0              Hollywood  26.01859  -80.12430  Entire home/apt             4
# 1       Hallandale Beach  25.97641  -80.12052  Entire home/apt             6
# 2            Dania Beach  26.03392  -80.14201  Entire home/apt             5
# 3      Southwest Ranches  26.04750  -80.36668  Entire home/apt             5
# 4              Hollywood  25.99414  -80.11814  Entire home/apt             5
#
#    beds  price  minimum_nights  maximum_nights has_availability  \
# 0   2.0  190.0              32            1125                t
# 1   4.0  140.0              30             365                t
# 2   3.0  127.0               7             180                t
# 3   3.0  235.0               4             180                t
# 4   2.0  324.0              20             365                t
#
#    availability_30  availability_60  availability_90  availability_365  \
# 0                2                2               10               214
# 1               19               19               19               281
# 2                0                1                1                 1
# 3               24               54               84               359
# 4                6               18               29               304
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                 58                      1                       0
# 1                  4                      2                       0
# 2                 31                      9                       1
# 3                  4                      0                       0
# 4                 27                      0                       0
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2013-01-03  2023-03-31                  4.63                    4.69
# 1   2021-03-27  2023-06-03                  4.00                    4.50
# 2   2011-11-01  2023-12-17                  4.77                    4.87
# 3   2012-08-06  2018-03-28                  5.00                    5.00
# 4   2011-08-23  2022-07-01                  4.29                    4.42
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.61                   5.00
# 1                       4.00                   4.75
# 2                       4.84                   4.94
# 3                       5.00                   5.00
# 4                       4.24                   4.44
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.97                    4.88                 4.71
# 1                         4.75                    5.00                 4.50
# 2                         4.90                    4.81                 4.87
# 3                         5.00                    4.25                 5.00
# 4                         4.32                    4.54                 4.08
#
#    reviews_per_month  bathrooms  vacancy_rate_30  vacancy_rate_60  \
# 0               0.43        1.0         0.066667         0.033333
# 1               0.12        2.0         0.633333         0.316667
# 2               0.21        1.0         0.000000         0.016667
# 3               0.03        2.0         0.800000         0.900000
# 4               0.18        1.5         0.200000         0.300000
#
#    vacancy_rate_90  vacancy_rate_365  listing_cluster  host_cluster_x  \
# 0         0.111111          0.586301                1               1
# 1         0.211111          0.769863                3               1
# 2         0.011111          0.002740                0               2
# 3         0.933333          0.983562                3               0
# 4         0.322222          0.832877                3               0
#
#    host_cluster_y  host_cluster
# 0               0             0
# 1               0             0
# 2               1             1
# 3               0             0
# 4               0             0

# %%
# Display unique values of property_type and room_type
unique_property_types = listings_cleaned['property_type'].unique()
unique_room_types = listings_cleaned['room_type'].unique()

print("Unique property types:")
print(unique_property_types)
print("\nUnique room types:")
print(unique_room_types)
# Out:
# Unique property types:
# ['Entire home' 'Entire rental unit' 'Entire condo'
#  'Private room in guest suite' 'Private room in guesthouse'
#  'Private room in condo' 'Entire townhouse' 'Entire guest suite'
#  'Private room in rental unit' 'Private room in home'
#  'Private room in bed and breakfast' 'Entire villa'
#  'Private room in townhouse' 'Entire cottage' 'Entire serviced apartment'
#  'Entire cabin' 'Room in boutique hotel' 'Private room in resort'
#  'Room in bed and breakfast' 'Private room in villa' 'Entire bungalow'
#  'Entire guesthouse' 'Entire chalet' 'Private room' 'Entire place'
#  'Room in aparthotel' 'Room in hotel' 'Private room in bungalow'
#  'Camper/RV' 'Barn' 'Room in serviced apartment' 'Room in resort' 'Boat'
#  'Casa particular' 'Private room in tiny home' 'Private room in farm stay'
#  'Private room in loft' 'Entire loft' 'Entire vacation home'
#  'Entire resort' 'Private room in casa particular' 'Tiny home'
#  'Private room in tent' 'Shared room in home' 'Entire timeshare'
#  'Shared room in condo' 'Shared room in rental unit' 'Houseboat'
#  'Private room in serviced apartment' 'Earthen home'
#  'Private room in barn' 'Shared room in townhouse' 'Island'
#  'Private room in cottage' 'Castle' 'Campsite' 'Lighthouse'
#  'Shared room in aparthotel' 'Shared room in hostel' 'Farm stay'
#  'Private room in vacation home' 'Private room in earthen home'
#  'Shared room in guest suite' 'Shared room in boutique hotel' 'Tent'
#  'Entire home/apt' 'Private room in camper/rv'
#  'Shared room in casa particular' 'Shared room in guesthouse'
#  'Private room in shipping container' 'Shared room in serviced apartment'
#  'Shared room in tiny home' 'Private room in boat' 'Tower']
#
# Unique room types:
# ['Entire home/apt' 'Private room' 'Hotel room' 'Shared room']

# %%
# Display unique values of the specified columns
unique_calculated_host_listings_count = listings_cleaned['calculated_host_listings_count'].unique()
unique_calculated_host_listings_count_entire_homes = listings_cleaned['calculated_host_listings_count_entire_homes'].unique()
unique_calculated_host_listings_count_private_rooms = listings_cleaned['calculated_host_listings_count_private_rooms'].unique()
unique_calculated_host_listings_count_shared_rooms = listings_cleaned['calculated_host_listings_count_shared_rooms'].unique()

print("Unique values for calculated_host_listings_count:")
print(unique_calculated_host_listings_count)
print("\nUnique values for calculated_host_listings_count_entire_homes:")
print(unique_calculated_host_listings_count_entire_homes)
print("\nUnique values for calculated_host_listings_count_private_rooms:")
print(unique_calculated_host_listings_count_private_rooms)
print("\nUnique values for calculated_host_listings_count_shared_rooms:")
print(unique_calculated_host_listings_count_shared_rooms)
# Out:
# Unique values for calculated_host_listings_count:
# [  2  15   1   5   4  23  12   3  10   7   6  30  21  14   8   9  36  77
#   50  16  11  13 177  20  31  39  18 137  27  32  56  40 106  25  42  44
#   60  22  28 110  29  43  59  41  75  19  17  35  45  55  63 356  51  46
#   34  26  38  24  84 118  62  73]
#
# Unique values for calculated_host_listings_count_entire_homes:
# [  2  15   1   5   4   0  23   3  10   7  30  21  11   8   9  36   6  77
#   50  16  13 177  20  12  31  39 112  14  18  27  32  56  40 106  25  42
#   44  60  22  28 109  17  59  41  75  19  35  45  43  55  63 353  51  46
#   34  29  33 105  24  84  26 118]
#
# Unique values for calculated_host_listings_count_private_rooms:
# [ 0  2  1 12  3  4  5  6  8 25  7  9 11 23 21 16 10 15 22 35 56 42 14]
#
# Unique values for calculated_host_listings_count_shared_rooms:
# [ 0  1 11  2  6  5  4  3]
